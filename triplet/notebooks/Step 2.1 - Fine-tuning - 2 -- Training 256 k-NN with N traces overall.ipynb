# %% [markdown]
# This notebook is used to train the k-NN models for key value guesses (from 0 to 255). A total of 256 k-NN models are trained and saved.
#
# Check that the parameters in the dictionary are correct before running this notebook. Verify the train_data_params dictionary under the "Parameters to train 256 k-NN classifiers" heading. The description of each parameter is as follows:
#
# - ~~input_path: The directory containing the dataset for training the k-NN models is specified by input path.~~
# - input_path: The file containing the dataset for training the k-NN models is specified by input path.
# - target_byte: The attack byte is designated as target byte.
# - start_idx: starting index of the attack window.
# - end_idx: last index of the attack window.
# - testType: The testType parameter is used to select the appropriate dataset with the same or different key as the training dataset. It is always "samekey" when training the k-NN models.
# - n: Number of samples to be utilized for training each k-NN model.
# - feat_extractor_path: Path to the triplet model to be utilized for extracting the features.
# - path_to_save_knns: Path to save the trained k-NN models.

# %%
import os, sys
# setting the utilities required for loading the data and training the model
sys.path.append('../utilities/')

from tripletEvalUtilities import *

# %load_ext autotime
# Out:
# <pre>✔️ 461 µs (2022-03-10T21:05:59/2022-03-10T21:05:59)</pre>

# %% [markdown]
# #### Parameters to train 256 k-NN classifiers

# %%
# parameters of the training dataset
train_data_params = {
    "input_path": '../../TripletPower-data/stm32f-unmasked/train-test-256-k-nn/PC2_CB2_TDS3_K6_U_2500/train_same_key.npz', # path load the training data
    "target_byte": 2,  # byte on which attack is to be performed
    "start_idx": 1200,
    "end_idx": 2200,
    "testType": "samekey",  # choices={'samekey', 'diffkey'}
    "n": 2500,
    "feat_extractor_path": '../models/feature-extractor-model/stm32f-unmasked/Triplet_Model_emb_size_512_epochs_10_target_byte_2_nsamples_100.hdf5', # path from where the triplet model is loaded
    "path_to_save_knns": "../models/256-k-nn-models/stm32f-unmasked/" # path to save the trained knn models
}
# Out:
# <pre>✔️ 746 µs (2022-03-10T21:05:59/2022-03-10T21:05:59)</pre>

# %%
def gen_features_and_labels_256_2(data, key_byte_value, input_target_byte, start_index, end_index):
    """
    This function generates features and labels for the dataset.
    """

    # loading the dataset
    power_traces, plain_text, key = data['power_trace'], data['plain_text'], data['key']

    print('generating features and labels for the key byte value: ', key_byte_value)

    # key byte is the value between 0 and 15
    labels = []
    for i in range(plain_text.shape[0]):
        text_i = plain_text[i]
        label = aes_internal(text_i[input_target_byte], key_byte_value) #key[i][input_key_byte]
        labels.append(label)

    labels = np.array(labels)
    if not isinstance(power_traces, np.ndarray):
        power_traces = np.array(power_traces)
    power_traces = power_traces[:, start_index:end_index]

    return power_traces, labels

def data_info(data):
    """
    This function prints the information of the dataset.
    """
    # loading the dataset
    power_traces, plain_text, key = data['power_trace'], data['plain_text'], data['key']

    print('shape of the power traces: ', power_traces.shape)
    print('shape of the plaintext : ', plain_text.shape)
    print('Ground Truth for the key : ', key)
# Out:
# <pre>✔️ 1.44 ms (2022-03-10T21:05:59/2022-03-10T21:05:59)</pre>

# %%
def load_data_knn_2(params, key_byte_value, data_label=None):
    """
    This function loads the dataset required.
    """
    print('preparing data for training k-NN model ...')
    target_byte = params['target_byte']
    start_idx, end_idx = params["start_idx"], params["end_idx"]
    file_name = params["input_path"]

    try:
        train_data_whole_pack = np.load(file_name)
    except OSError:
        print("could not access {}".format(file_name))
        sys.exit()
    else:
        data_info(train_data_whole_pack)

    print('-'*80)
    print('processing data for key byte value: ', key_byte_value)
    power_traces, labels = gen_features_and_labels_256_2(train_data_whole_pack,
                                                        key_byte_value,
                                                         target_byte,
                                                        start_idx, end_idx)

    power_traces = power_traces[:params["n"], :]
    labels = labels[:params["n"]]

    print('reshaped power traces: ', power_traces.shape)
    print('shape of the labels: ', labels.shape)

    return power_traces, labels
# Out:
# <pre>✔️ 1.53 ms (2022-03-10T21:05:59/2022-03-10T21:05:59)</pre>

# %%
def train_knn_256(x_train, y_train, key_byte_index=None, model_path=None, neighbours=None, eval_type=None):
    """
    This function trains and test the k-NN model.
    :param x_train: the dataset used for training the k-NN
    :param y_train: the labels corresponding to the power traces in x_train
    :param x_test: the dataset used for evaluating the performance of K-NN
    :param y_test: the labels corresponding to the power traces in x_test
    :param neighbours:  Number of neighbors to use by default for kneighbors queries
    :param eval_type: either N-MEV or N-ALL
    :return: prediction of each testing trace
    """
    # ::TODO: Add data manipulation for N-MEV

    knn = KNeighborsClassifier(n_neighbors=neighbours,
                               # n-shot Number of neighbors to use by default for kneighbors queries. n for n-shot learning
                               weights='distance',
                               p=2,  # Power parameter for the Minkowski metric.
                               metric='cosine',  # the distance metric to use for the tree.
                               algorithm='brute'  # Algorithm used to compute the nearest neighbors
                               )
    knn.fit(x_train, y_train)

    model_name = 'knn-key-value-' + str(key_byte_index) + '.model'
    #     model_name = 'knn-all-class-nshot' + train_data_params["n"] +'.model'
    model_path = os.path.join(model_path, model_name)
    dump(knn, model_path)

    if (key_byte_index % 25) == 0:
        print('model for class %d saved successfully!' % (key_byte_index))
        print('-'*80)
# Out:
# <pre>✔️ 1.24 ms (2022-03-10T21:05:59/2022-03-10T21:05:59)</pre>

# %%
# loading the feature extractor for extracting features of the power traces
input_shape = (train_data_params["end_idx"] - train_data_params["start_idx"], 1)
emb_size = 512
feat_extractor_path = train_data_params["feat_extractor_path"]
feature_extractor_model = load_feature_extractor(feat_extractor_path)
print('-' * 90)
# Out:
# <pre>✔️ 1.4 s (2022-03-10T21:05:59/2022-03-10T21:06:01)</pre>
# loading the feature extractor for ../models/feature-extractor-model/stm32f-unmasked/Triplet_Model_emb_size_512_epochs_10_target_byte_2_nsamples_100.hdf5 ...
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# feature extractor loaded successfully!
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 1000, 1)]         0
# _________________________________________________________________
# block1_conv1 (Conv1D)        (None, 500, 64)           768
# _________________________________________________________________
# block1_pool (AveragePooling1 (None, 250, 64)           0
# _________________________________________________________________
# block2_conv1 (Conv1D)        (None, 250, 128)          90240
# _________________________________________________________________
# block2_pool (AveragePooling1 (None, 125, 128)          0
# _________________________________________________________________
# block3_conv1 (Conv1D)        (None, 125, 256)          360704
# _________________________________________________________________
# block3_pool (AveragePooling1 (None, 62, 256)           0
# _________________________________________________________________
# block4_conv1 (Conv1D)        (None, 62, 512)           1442304
# _________________________________________________________________
# block4_pool (AveragePooling1 (None, 31, 512)           0
# _________________________________________________________________
# block5_conv1 (Conv1D)        (None, 31, 512)           2884096
# _________________________________________________________________
# block5_pool (AveragePooling1 (None, 15, 512)           0
# _________________________________________________________________
# flatten (Flatten)            (None, 7680)              0
# _________________________________________________________________
# feature_vector (Dense)       (None, 512)               3932672
# =================================================================
# Total params: 8,710,784
# Trainable params: 8,710,784
# Non-trainable params: 0
# _________________________________________________________________
# None
# ------------------------------------------------------------------------------------------

# %%
# training and testing k-NN
eval_type = "N-ALL" # or N-ALL or N-MEV

model_path = os.path.join(train_data_params["path_to_save_knns"], "knn-256-models-n-" + str(train_data_params["n"]) + "-traces-target-byte-" + str(train_data_params["target_byte"]))
if not os.path.isdir(model_path):
    os.makedirs(model_path)
# Out:
# <pre>✔️ 33.5 ms (2022-03-10T21:06:01/2022-03-10T21:06:01)</pre>

# %%
key_byte_values = np.arange(0, 256, 1)
# Out:
# <pre>✔️ 611 µs (2022-03-10T21:06:01/2022-03-10T21:06:01)</pre>

# %%
for i in range(len(key_byte_values)):
    print('*'*80)
    
    x_train, y_train = load_data_knn_2(train_data_params, key_byte_values[i], data_label='train')
    # extracting features from the training set and testing set
    x_train_feature_set = extract_features_train(feature_extractor_model, x_train) 
    print('shape of x_train_feature_set: ', x_train_feature_set.shape)
    
    print('Trainng k-NN model ...')
    # train k-NN classifier for respective class
    train_knn_256(x_train_feature_set, y_train, i, model_path=model_path, 
              neighbours=100,
              eval_type=eval_type)
    print('k-NN model for guessed key value %d trained successfully!'%(i))

print('all the 256 k-NN models saved successfully!')
# Out:
# <pre>✔️ 7 min 27 s (2022-03-10T21:06:01/2022-03-10T21:13:29)</pre>
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  0
# generating features and labels for the key byte value:  0
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# model for class 0 saved successfully!
# --------------------------------------------------------------------------------
# k-NN model for guessed key value 0 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  1
# generating features and labels for the key byte value:  1
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 1 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  2
# generating features and labels for the key byte value:  2
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 2 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  3
# generating features and labels for the key byte value:  3
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 3 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  4
# generating features and labels for the key byte value:  4
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 4 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  5
# generating features and labels for the key byte value:  5
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 5 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  6
# generating features and labels for the key byte value:  6
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 6 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  7
# generating features and labels for the key byte value:  7
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 7 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  8
# generating features and labels for the key byte value:  8
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 8 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  9
# generating features and labels for the key byte value:  9
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 9 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  10
# generating features and labels for the key byte value:  10
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 10 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  11
# generating features and labels for the key byte value:  11
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 11 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  12
# generating features and labels for the key byte value:  12
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 12 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  13
# generating features and labels for the key byte value:  13
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 13 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  14
# generating features and labels for the key byte value:  14
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 14 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  15
# generating features and labels for the key byte value:  15
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 15 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  16
# generating features and labels for the key byte value:  16
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 16 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  17
# generating features and labels for the key byte value:  17
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 17 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  18
# generating features and labels for the key byte value:  18
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 18 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  19
# generating features and labels for the key byte value:  19
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 19 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  20
# generating features and labels for the key byte value:  20
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 20 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  21
# generating features and labels for the key byte value:  21
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 21 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  22
# generating features and labels for the key byte value:  22
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 22 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  23
# generating features and labels for the key byte value:  23
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 23 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  24
# generating features and labels for the key byte value:  24
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 24 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  25
# generating features and labels for the key byte value:  25
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# model for class 25 saved successfully!
# --------------------------------------------------------------------------------
# k-NN model for guessed key value 25 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  26
# generating features and labels for the key byte value:  26
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 26 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  27
# generating features and labels for the key byte value:  27
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 27 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  28
# generating features and labels for the key byte value:  28
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 28 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  29
# generating features and labels for the key byte value:  29
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 29 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  30
# generating features and labels for the key byte value:  30
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 30 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  31
# generating features and labels for the key byte value:  31
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 31 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  32
# generating features and labels for the key byte value:  32
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 32 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  33
# generating features and labels for the key byte value:  33
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 33 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  34
# generating features and labels for the key byte value:  34
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 34 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  35
# generating features and labels for the key byte value:  35
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 35 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  36
# generating features and labels for the key byte value:  36
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 36 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  37
# generating features and labels for the key byte value:  37
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 37 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  38
# generating features and labels for the key byte value:  38
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 38 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  39
# generating features and labels for the key byte value:  39
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 39 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  40
# generating features and labels for the key byte value:  40
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 40 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  41
# generating features and labels for the key byte value:  41
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 41 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  42
# generating features and labels for the key byte value:  42
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 42 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  43
# generating features and labels for the key byte value:  43
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 43 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  44
# generating features and labels for the key byte value:  44
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 44 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  45
# generating features and labels for the key byte value:  45
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 45 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  46
# generating features and labels for the key byte value:  46
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 46 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  47
# generating features and labels for the key byte value:  47
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 47 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  48
# generating features and labels for the key byte value:  48
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 48 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  49
# generating features and labels for the key byte value:  49
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 49 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  50
# generating features and labels for the key byte value:  50
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# model for class 50 saved successfully!
# --------------------------------------------------------------------------------
# k-NN model for guessed key value 50 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  51
# generating features and labels for the key byte value:  51
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 51 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  52
# generating features and labels for the key byte value:  52
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 52 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  53
# generating features and labels for the key byte value:  53
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 53 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  54
# generating features and labels for the key byte value:  54
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 54 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  55
# generating features and labels for the key byte value:  55
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 55 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  56
# generating features and labels for the key byte value:  56
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 56 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  57
# generating features and labels for the key byte value:  57
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 57 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  58
# generating features and labels for the key byte value:  58
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 58 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  59
# generating features and labels for the key byte value:  59
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 59 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  60
# generating features and labels for the key byte value:  60
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 60 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  61
# generating features and labels for the key byte value:  61
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 61 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  62
# generating features and labels for the key byte value:  62
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 62 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  63
# generating features and labels for the key byte value:  63
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 63 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  64
# generating features and labels for the key byte value:  64
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 64 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  65
# generating features and labels for the key byte value:  65
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 65 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  66
# generating features and labels for the key byte value:  66
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 66 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  67
# generating features and labels for the key byte value:  67
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 67 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  68
# generating features and labels for the key byte value:  68
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 68 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  69
# generating features and labels for the key byte value:  69
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 69 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  70
# generating features and labels for the key byte value:  70
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 70 trained successfully!
# ********************************************************************************
# ...
# --------------------------------------------------------------------------------
# processing data for key byte value:  232
# generating features and labels for the key byte value:  232
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 232 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  233
# generating features and labels for the key byte value:  233
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 233 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  234
# generating features and labels for the key byte value:  234
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 234 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  235
# generating features and labels for the key byte value:  235
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 235 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  236
# generating features and labels for the key byte value:  236
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 236 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  237
# generating features and labels for the key byte value:  237
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 237 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  238
# generating features and labels for the key byte value:  238
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 238 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  239
# generating features and labels for the key byte value:  239
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 239 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  240
# generating features and labels for the key byte value:  240
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 240 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  241
# generating features and labels for the key byte value:  241
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 241 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  242
# generating features and labels for the key byte value:  242
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 242 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  243
# generating features and labels for the key byte value:  243
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 243 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  244
# generating features and labels for the key byte value:  244
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 244 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  245
# generating features and labels for the key byte value:  245
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 245 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  246
# generating features and labels for the key byte value:  246
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 246 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  247
# generating features and labels for the key byte value:  247
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 247 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  248
# generating features and labels for the key byte value:  248
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 248 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  249
# generating features and labels for the key byte value:  249
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 249 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  250
# generating features and labels for the key byte value:  250
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# model for class 250 saved successfully!
# --------------------------------------------------------------------------------
# k-NN model for guessed key value 250 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  251
# generating features and labels for the key byte value:  251
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 251 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  252
# generating features and labels for the key byte value:  252
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 252 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  253
# generating features and labels for the key byte value:  253
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 253 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  254
# generating features and labels for the key byte value:  254
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 254 trained successfully!
# ********************************************************************************
# preparing data for training k-NN model ...
# shape of the power traces:  (20000, 5000)
# shape of the plaintext :  (20000, 16)
# Ground Truth for the key :  [198  91  97  57 152  71 214 101 138  74  78  84  27 234  87  22]
# --------------------------------------------------------------------------------
# processing data for key byte value:  255
# generating features and labels for the key byte value:  255
# reshaped power traces:  (2500, 1000)
# shape of the labels:  (2500,)
# shape of x_train_feature_set:  (2500, 512)
# Trainng k-NN model ...
# k-NN model for guessed key value 255 trained successfully!
# all the 256 k-NN models saved successfully!
